# %%
import pandas as pd

import numpy as np

from sklearn import metrics

import os

os.getcwd()
# Out:
# 'C:\\Users\\Onkar'

# %%
training = pd.read_csv('train.csv', sep=',')

training.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-4a72fe6d06a8> in <module>
# ----> 1 training = pd.read_csv('train.csv', sep=',')
#       2
#       3 training.head(10)
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'train.csv' does not exist: b'train.csv'

# %%
training = pd.read_csv('train.csv', sep=',')

training.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
training = pd.read_csv('train.csv', sep=',')

training.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4a72fe6d06a8> in <module>
# ----> 1 training = pd.read_csv('train.csv', sep=',')
#       2
#       3 training.head(10)
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'train.csv' does not exist: b'train.csv'

# %%
training = pd.read_csv('train.csv', sep=',')

training.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
training['Cabin'].fillna(0).value_counts()

#Drop the unnecessary columns before proceeding.

training = training.drop(['Name', 'Ticket', 'Cabin'], axis=1)

training.head(10)

#Now take a look to see if there is any missing data.
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S
# 5            6         0       3    male   NaN      0      0   8.4583        Q
# 6            7         0       1    male  54.0      0      0  51.8625        S
# 7            8         0       3    male   2.0      3      1  21.0750        S
# 8            9         1       3  female  27.0      0      2  11.1333        S
# 9           10         1       2  female  14.0      1      0  30.0708        C

# %%
training['Embarked'].value_counts().plot(kind='bar')

training['Embarked'] = training['Embarked'].fillna('S')

training = training.fillna(0)

# %%
embarked_dummies = pd.get_dummies(training['Embarked'])

embarked_dummies.head(10)
# Out:
#    C  Q  S
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  0  1
# 5  0  1  0
# 6  0  0  1
# 7  0  0  1
# 8  0  0  1
# 9  1  0  0

# %%
training = training.join(embarked_dummies)

training.head(10)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
# 5            6         0       3    male   0.0      0      0   8.4583
# 6            7         0       1    male  54.0      0      0  51.8625
# 7            8         0       3    male   2.0      3      1  21.0750
# 8            9         1       3  female  27.0      0      2  11.1333
# 9           10         1       2  female  14.0      1      0  30.0708
#
#   Embarked  C  Q  S
# 0        S  0  0  1
# 1        C  1  0  0
# 2        S  0  0  1
# 3        S  0  0  1
# 4        S  0  0  1
# 5        Q  0  1  0
# 6        S  0  0  1
# 7        S  0  0  1
# 8        S  0  0  1
# 9        C  1  0  0

# %%
sex_dummies = pd.get_dummies(training['Sex'])

training = training.join(sex_dummies)

training = training.drop(['Embarked', 'Sex'], axis=1)

training.head(10)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  C  Q  S  \
# 0            1         0       3  22.0      1      0   7.2500  0  0  1
# 1            2         1       1  38.0      1      0  71.2833  1  0  0
# 2            3         1       3  26.0      0      0   7.9250  0  0  1
# 3            4         1       1  35.0      1      0  53.1000  0  0  1
# 4            5         0       3  35.0      0      0   8.0500  0  0  1
# 5            6         0       3   0.0      0      0   8.4583  0  1  0
# 6            7         0       1  54.0      0      0  51.8625  0  0  1
# 7            8         0       3   2.0      3      1  21.0750  0  0  1
# 8            9         1       3  27.0      0      2  11.1333  0  0  1
# 9           10         1       2  14.0      1      0  30.0708  1  0  0
#
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1
# 5       0     1
# 6       0     1
# 7       0     1
# 8       1     0
# 9       1     0

# %%
training = training.drop(['S', 'male'], axis=1)

training.head(10)

training.describe() #Summarize the data.

#Doesn't make sense to see 0 for 'Fare' so do a quick sanity check using a histogram. Looks good enough to leave in there

training['Fare'].hist(bins=100)

#A simple groupby to see if survival rates seem to differ by some of the variables.

training['Survived'].mean()

#What did our model baseline just become? Hint: It's not 50/50.

training['Survived'].groupby(training['female']).mean()
# Out:
# female
# 0    0.188908
# 1    0.742038
# Name: Survived, dtype: float64

# %%
training_data = training.values[:,2:]

training_target = training.values[:,1]

training_target[:5]

#Bring in the test dataset and apply the same basic transformations.

test = pd.read_csv('test.csv', sep=',')

test = test.drop(['Name', 'Ticket', 'Cabin'], axis=1)

test['Embarked'] = test['Embarked'].fillna(method='ffill')

test = test.fillna(0)

embarked_dummies = pd.get_dummies(test['Embarked'])

test = test.join(embarked_dummies)

sex_dummies = pd.get_dummies(test['Sex'])

test = test.join(sex_dummies)

test = test.drop(['Embarked', 'Sex'], axis=1)

test = test.drop(['S', 'male'], axis=1)

test_data = test.values

test_data[:3]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-30309499a833> in <module>
#       7 #Bring in the test dataset and apply the same basic transformations.
#       8
# ----> 9 test = pd.read_csv('Data/test.csv', sep=',')
#      10
#      11 test = test.drop(['Name', 'Ticket', 'Cabin'], axis=1)
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'Data/test.csv' does not exist: b'Data/test.csv'

# %%
training_data = training.values[:,2:]

training_target = training.values[:,1]

training_target[:5]

#Bring in the test dataset and apply the same basic transformations.

test = pd.read_csv('test.csv', sep=',')

test = test.drop(['Name', 'Ticket', 'Cabin'], axis=1)

test['Embarked'] = test['Embarked'].fillna(method='ffill')

test = test.fillna(0)

embarked_dummies = pd.get_dummies(test['Embarked'])

test = test.join(embarked_dummies)

sex_dummies = pd.get_dummies(test['Sex'])

test = test.join(sex_dummies)

test = test.drop(['Embarked', 'Sex'], axis=1)

test = test.drop(['S', 'male'], axis=1)

test_data = test.values

test_data[:3]
# Out:
# array([[892.    ,   3.    ,  34.5   ,   0.    ,   0.    ,   7.8292,
#           0.    ,   1.    ,   0.    ],
#        [893.    ,   3.    ,  47.    ,   1.    ,   0.    ,   7.    ,
#           0.    ,   0.    ,   1.    ],
#        [894.    ,   2.    ,  62.    ,   0.    ,   0.    ,   9.6875,
#           0.    ,   1.    ,   0.    ]])

# %%
from sklearn.ensemble

import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators = 1000)

rf_model.fit(training_data, training_target)

print(rf_model)
# Out:
#   File "<ipython-input-14-1f172f8d71a6>", line 1
#     from sklearn.ensemble
#                          ^
# SyntaxError: invalid syntax

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators = 1000)

rf_model.fit(training_data, training_target)

print(rf_model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
expected = training_target

predicted = rf_model.predict(training_data)

print(metrics.accuracy_score(expected, predicted))

print(metrics.confusion_matrix(expected, predicted))

print(metrics.roc_auc_score(expected, predicted))
# Out:
# 0.9820426487093153
# [[543   6]
#  [ 10 332]]
# 0.9799156360847474

# %%
from sklearn import cross_validation

from sklearn.linear_model import LogisticRegression

num_folds = 10

num_instances = len(training_data)

kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds)

model = LogisticRegression()

results = cross_validation.cross_val_score(model, training_data, training_target, cv=kfold)

print(results)

print(results.mean())

print(results.std())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-36d882349502> in <module>
# ----> 1 from sklearn import cross_validation
#       2
#       3 from sklearn.linear_model import LogisticRegression
#       4
#       5 num_folds = 10
#
# ImportError: cannot import name 'cross_validation' from 'sklearn' (E:\Anaconda\lib\site-packages\sklearn\__init__.py)

# %%
from sklearn.model_selection import cross_validate

# %%
from sklearn.model_selection import cross_validate

from sklearn.linear_model import LogisticRegression

num_folds = 10

num_instances = len(training_data)

kfold = cross_validate.KFold(n=num_instances, n_folds=num_folds)

model = LogisticRegression()

results = cross_validate.cross_val_score(model, training_data, training_target, cv=kfold)

print(results)

print(results.mean())

print(results.std())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-a8d0805578f5> in <module>
#       7 num_instances = len(training_data)
#       8
# ----> 9 kfold = cross_validate.KFold(n=num_instances, n_folds=num_folds)
#      10
#      11 model = LogisticRegression()
#
# AttributeError: 'function' object has no attribute 'KFold'

# %%
predicted = rf_model.predict(test_data[:,1:])

submission = np.c_[test_data[:,0].astype(int), predicted.astype(int)]

submission = pd.DataFrame(submission, columns=['PassengerId', 'Survived'])

submission.to_csv('Data/submission_rf.csv', index=False)

submission.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-3d7b3c2b6e4e> in <module>
#       5 submission = pd.DataFrame(submission, columns=['PassengerId', 'Survived'])
#       6
# ----> 7 submission.to_csv('Data/submission_rf.csv', index=False)
#       8
#       9 submission.head()
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# E:\Anaconda\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# E:\Anaconda\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/submission_rf.csv'

# %%
from sklearn import cross_validation

from sklearn.linear_model import LogisticRegression

num_folds = 10

num_instances = len(training_data)

kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds)

model = LogisticRegression()

results = cross_validation.cross_val_score(model, training_data, training_target, cv=kfold)

print(results)

print(results.mean())

print(results.std())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-36d882349502> in <module>
# ----> 1 from sklearn import cross_validation
#       2
#       3 from sklearn.linear_model import LogisticRegression
#       4
#       5 num_folds = 10
#
# ImportError: cannot import name 'cross_validation' from 'sklearn' (E:\Anaconda\lib\site-packages\sklearn\__init__.py)

# %%
from sklearn.model_selection import cross_validate

from sklearn.linear_model import LogisticRegression

num_folds = 10

num_instances = 20

kfold = cross_validate.KFold(n=num_instances, n_folds=num_folds)

model = LogisticRegression()

results = cross_validate.cross_val_score(model, training_data, training_target, cv=kfold)

print(results)

print(results.mean())

print(results.std())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a8d0805578f5> in <module>
#       5 num_folds = 10
#       6
# ----> 7 num_instances = len(training_data)
#       8
#       9 kfold = cross_validate.KFold(n=num_instances, n_folds=num_folds)
#
# NameError: name 'training_data' is not defined

# %%
from sklearn.model_selection import cross_validate

from sklearn.linear_model import LogisticRegression

num_folds = 10

num_instances = 20

kfold = cross_validate.KFold(n=num_instances, n_folds=num_folds)

model = LogisticRegression()

results = cross_validate.cross_val_score(model, training_data, training_target, cv=kfold)

print(results)

print(results.mean())

print(results.std())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-522e50e3f1b3> in <module>
#       7 num_instances = 20
#       8
# ----> 9 kfold = cross_validate.KFold(n=num_instances, n_folds=num_folds)
#      10
#      11 model = LogisticRegression()
#
# AttributeError: 'function' object has no attribute 'KFold'

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import Kfold

from sklearn.linear_model import LogisticRegression

num_folds = 10

num_instances = len(training_data)

kfold = cross_validate.KFold(n=num_instances, n_folds=num_folds)

model = LogisticRegression()

results = cross_validate.cross_val_score(model, training_data, training_target, cv=kfold)

print(results)

print(results.mean())

print(results.std())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-2c64ecf55896> in <module>
#       1 from sklearn.model_selection import cross_validate
# ----> 2 from sklearn.model_selection import Kfold
#       3
#       4 from sklearn.linear_model import LogisticRegression
#       5
#
# ImportError: cannot import name 'Kfold' from 'sklearn.model_selection' (E:\Anaconda\lib\site-packages\sklearn\model_selection\__init__.py)

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold

from sklearn.linear_model import LogisticRegression

num_folds = 10

num_instances = 20

kfold = cross_validate.KFold(n=num_instances, n_folds=num_folds)

model = LogisticRegression()

results = cross_validate.cross_val_score(model, training_data, training_target, cv=kfold)

print(results)

print(results.mean())

print(results.std())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f0beb3637cd6> in <module>
#       6 num_folds = 10
#       7
# ----> 8 num_instances = len(training_data)
#       9
#      10 kfold = cross_validate.KFold(n=num_instances, n_folds=num_folds)
#
# NameError: name 'training_data' is not defined

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold

from sklearn.linear_model import LogisticRegression

num_folds = 10

num_instances = 20

kfold = cross_validate.KFold(n=num_instances, n_folds=num_folds)

model = LogisticRegression()

results = cross_validate.cross_val_score(model, training_data, training_target, cv=kfold)

print(results)

print(results.mean())

print(results.std())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-4109780997e7> in <module>
#       8 num_instances = 20
#       9
# ---> 10 kfold = cross_validate.KFold(n=num_instances, n_folds=num_folds)
#      11
#      12 model = LogisticRegression()
#
# AttributeError: 'function' object has no attribute 'KFold'

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold

from sklearn.linear_model import LogisticRegression

num_folds = 10

num_instances = 20

kfold = KFold(n=num_instances, n_folds=num_folds)

model = LogisticRegression()

results = cross_validate.cross_val_score(model, training_data, training_target, cv=kfold)

print(results)

print(results.mean())

print(results.std())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-52e3749b225c> in <module>
#       8 num_instances = 20
#       9
# ---> 10 kfold = KFold(n=num_instances, n_folds=num_folds)
#      11
#      12 model = LogisticRegression()
#
# TypeError: __init__() got an unexpected keyword argument 'n'

# %%
training.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fc9901634818> in <module>
# ----> 1 training.head(5)
#
# NameError: name 'training' is not defined
